# %% [markdown]
# # Introduction to Python
#
# USP 410/510 Urban Data Science — Week 1
#
# Based on Downey, *Think Python*, [Chapter 1](https://allendowney.github.io/ThinkPython/chap01.html)

# %% [markdown]
# ## Arithmetic in Python
#
# Python can be used as a calculator. Try each of these:

# %%
30 + 12        # Addition

# %%
43 - 1         # Subtraction

# %%
6 * 7          # Multiplication

# %%
84 / 2         # Division — always returns a float!

# %%
85 // 2        # Integer division

# %%
7 ** 2         # Exponentiation

# %% [markdown]
# ### Order of operations
#
# Same as math (PEMDAS):

# %%
(12 + 5) * 6   # Parentheses first → 102

# %%
12 + 5 * 6     # Multiplication before addition → 42

# %% [markdown]
# ## Data Types
#
# Every value in Python has a **type**:

# %%
type(42)       # int — integer (whole numbers)

# %%
type(42.0)     # float — floating point (decimals)

# %%
type('hello')  # str — string (text)

type(b'0x001')
# Out:
# bytes

# %% [markdown]
# ### Type conversion
#
# You can convert between types:

# %%
int(42.9)      # Truncates, does not round!

# %%
float(42)

# %%
str(42)

# %% [markdown]
# **Watch out:** division always returns a float:

# %%
84 / 2         # Returns 42.0, not 42

# %% [markdown]
# ## Strings
#
# Text is enclosed in quotes (single `'...'` or double `"..."`):

# %%
'Hello' + ' ' + 'World'   # Concatenation

# %%
'Spam, ' * 3               # Repetition
# Out:
# 'Spam, Spam, Spam, '

# %%
len('Portland')            # Length

# %% [markdown]
# `+` and `*` behave differently for strings vs. numbers:

# %%
3 + 4          # Arithmetic → 7

# %%
'3' + '4'      # Concatenation → '34'

# %% [markdown]
# **Common error** — you can't mix strings and numbers with `+`:

# %%
int('3') + 4        # TypeError! Try it and read the error message.
# Out:
# 7

# %% [markdown]
# ## Built-in Functions

# %%
round(3.14159)       # → 3

# %%
round(3.14159, 2)    # → 3.14

# %%
abs(-7)              # → 7

# %%
len('data science')  # → 12

# %%
type(42)             # → <class 'int'>

# %%
print('Hello!')

# %% [markdown]
# ## Try It Yourself
#
# Work through these exercises:

# %%
# What is your age in days (approximately)?
age_years = 25
age_days = age_years * 365
print(age_days)

# %%
# How many seconds in a year?
seconds_per_year = 365 * 24 * 60 * 60
print(seconds_per_year)

# %%
# What type is each of these?
print(type(age_years))
print(type(age_years / 2))
print(type('Portland'))

# %%
# Experiment: What happens when you divide by zero?
age_years / 0
# Out:
# Running cells with '.venv (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/lmwang/Nextcloud/usp510/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
